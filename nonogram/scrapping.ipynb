# %%
import requests
import urllib3
from bs4 import BeautifulSoup
import re

# %%
URL = "https://www.puzzle-nonograms.com/?size=3"

# %%
http = urllib3.PoolManager()
r = http.request('GET', URL)
soup = BeautifulSoup(r.data)

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <title>
#    Nonograms - online puzzle game
#   </title>
#   <meta content="Play online Nonograms the puzzle game also known as Hanjie or Paint by Numbers" name="description"/>
#   <meta content="nonograms,nonogram,hanjie,puzzle,game,paint by numbers,nanograms" name="keywords"/>
#   <meta content="NOINDEX,FOLLOW" name="ROBOTS"/>
#   <link href="https://www.puzzle-nonograms.com/" rel="canonical"/>
#   <link href="https://bg.puzzle-nonograms.com/?size=3" hreflang="bg" rel="alternate"/>
#   <link href="https://de.puzzle-nonograms.com/?size=3" hreflang="de" rel="alternate"/>
#   <link href="https://nl.puzzle-nonograms.com/?size=3" hreflang="nl" rel="alternate"/>
#   <link href="https://ro.puzzle-nonograms.com/?size=3" hreflang="ro" rel="alternate"/>
# ...

# %%
game = soup.find_all("script", type="text/javascript")[1].string

# %%
game
# Out:
# " var Game = {}; var Puzzle = {}; var task = '13/1.3.7/1.3/1.1.3/6.3/1.1.5/7/3.5/3.5/7.6.1/5.1.3/4.6/6.3/18/15.2/3.1.12/3.2.4.1/4.1.1/9/10/1.1.4.2/1.1.4.2/1.3.4.2/3.3.2/4.8.3/1.6.3/3.11/2.2.10/1.3.4.2/2.3.2.3.1/2.5.3/2.11/1.12/2.11/2.4.1.4/2.1.1.1/2.1.1.5/5.3/5/5'; var loadedId = 0; $(document).ready(function(){ Game = $('#game').nonograms({ ident: 'nonograms.3' , task: task, token: document.forms['answerForm'].param.value, puzzleID: $('#puzzleID').text(), puzzleWidth: 20, puzzleHeight: 20 ,localTimer: new Date().getTime() ,relativeTo: '#puzzleContainerOverflowDiv' ,noCheck: true ,separatorWidth: 1 ,onLoaded: function() { updateCheckpoints(); } }).initGame(); $(window).on('scroll', function() { }); Game.panzoomAction = function() { this.zoomingPanning = true; this.repositionHelpers(); }; var savedState; if ( (savedState = Game.getSaved()) && (!loadedId || (loadedId == Game.getSaved().puzzleID.replaceAll(',', ''))) ) { if (!savedState.savedState.solved || 0 || 0) { Game.loadGame(saved
# ...

# %%
x = re.findall("var task .*';", game)

# %%
res = 0
for i in x[0]:
    if i=="/":
        res+=1
res
# Out:
# 39

# %%
board = x[0]

# %%
re.split("/", x[0])
# Out:
# ["var task = '13",
#  '1.3.7',
#  '1.3',
#  '1.1.3',
#  '6.3',
#  '1.1.5',
#  '7',
#  '3.5',
#  '3.5',
#  '7.6.1',
#  '5.1.3',
#  '4.6',
#  '6.3',
#  '18',
#  '15.2',
#  '3.1.12',
#  '3.2.4.1',
#  '4.1.1',
#  '9',
#  '10',
#  '1.1.4.2',
#  '1.1.4.2',
#  '1.3.4.2',
#  '3.3.2',
#  '4.8.3',
#  '1.6.3',
#  '3.11',
#  '2.2.10',
#  '1.3.4.2',
#  '2.3.2.3.1',
#  '2.5.3',
#  '2.11',
#  '1.12',
#  '2.11',
#  '2.4.1.4',
#  '2.1.1.1',
#  '2.1.1.5',
#  '5.3',
#  '5',
#  "5';"]
